# %% [markdown]
# # Part 3. 최적의 설치 위치 제안

# %%
# matplotlib 한글 깨짐 잡아주는 방법 
# https://pinkwink.kr/1255
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans 
import warnings 
warnings.filterwarnings('ignore')

# %%
ind = [76,
 65,
 25,
 75,
 56,
 33,
 32,
 83,
 84,
 10,
 26,
 45,
 87,
 86,
 85,
 22,
 11,
 80,
 82,
 9,
 44,
 103,
 19,
 90,
 95,
 68,
 77,
 53,
 91,
 14,
 36,
 16,
 27]

# %% [markdown]
# ## 1. 데이터 로딩 및 이해

# %%
df_loc = pd.read_csv('/content/drive/My Drive/Colab Notebooks/군집분석_데이터/potential_locations.csv', encoding = 'cp949')
df_loc.head() # need 33 new chargers from Law of Large Numbers and CLT
# Out:
#         Name Type   Latitude   Longitude
# 0   애니카랜드상도점  정비장  37.501859  126.934700
# 1   제일자동차공업사  정비장  37.508751  126.931711
# 2   대성자동차공업사  정비장  37.497909  126.922863
# 3  BK Motors  정비장  37.481771  126.978283
# 4  스마일자동차공업사  정비장  37.486928  126.974458

# %% [markdown]
# ## 2. 결과 도출

# %%
kmeans_result_df = df_loc.iloc[ind]
kmeans_result_df
# Out:
#                  Name Type   Latitude   Longitude
# 76                한누리  주차장  37.477255  126.976864
# 65       선일하이테크 자동차정비  정비장  37.503124  126.934879
# 25           명수자동차공업사  정비장  37.508232  126.962601
# 75                 서광  주차장  37.488794  126.907841
# 56   현대자동차(주) 남부서비스센터  정비장  37.513946  126.934446
# 33      쌍용자동차동작서비스프라자  정비장  37.498697  126.951928
# 32           거성자동차공업사  정비장  37.499667  126.923606
# 83              동작갯마을  주차장  37.495784  126.982445
# 84        대성산업㈜노량진주유소  세차장  37.513511  126.944845
# 10           남부자동차공업사  정비장  37.484058  126.972810
# 26           진영자동차공업사  정비장  37.484858  126.976844
# 45              타이어테크  정비장  37.501853  126.949169
# 87         동일석유㈜동주충전소  세차장  37.499417  126.928834
# 86           대방자동차공업사  세차장  37.505551  126.927448
# 85           금양자동차공업사  세차장  37.499554  126.944605
# 22       한국지엠동작 바로서비스  정비장  37.494368  126.955641
# 11           성락자동차공업사  정비장  37.505355  126.961108
# 80             동작구청부설  주차장  37.512529  126.939944
# 82             보라매병원앞  주차장  37.491638  126.922823
# 9            혜원자동차공업사  정비장  37.512183  126.932147
# 44       (주)케이에스케이자동차  정비장  37.505326  126.950659
# 103          동작어린이도서관  도서관  37.509204  126.943434
# 19              상도남부점  정비장  37.505058  126.943794
# 90           경동자동차공업사  세차장  37.499456  126.918842
# 95    현대오일뱅크㈜ 사당셀프주유소  세차장  37.483071  126.972763
# 68              두리모터스  정비장  37.497856  126.921613
# 77                 도화  주차장  37.499808  126.935245
# 53          사람과자동차공업사  정비장  37.507632  126.949543
# 91              원일세차장  세차장  37.487145  126.966129
# 14              연합오토샵  정비장  37.504335  126.937542
# 36           우승자동차공업사  정비장  37.481613  126.980942
# 16           만도자동차공업사  정비장  37.487658  126.911963
# 27           경문자동차공업사  정비장  37.489495  126.981559

# %% [markdown]
# ## 3. 결과 시각화 및 저장

# %%
fig, ax = plt.subplots()
plt.scatter(kmeans_result_df['Latitude'], kmeans_result_df['Longitude'])
ax.ticklabel_format(useOffset=False)
plt.xlabel('위도')
plt.ylabel('경도', rotation = 0, labelpad = 15)
plt.title('최적의 확충 위치 (공공장소 경위도)')
plt.show() # 이상치 4개 제거 필요 (맨위 2개 있음)

# %%
kmeans_result_df.to_csv('clust_result.csv')
